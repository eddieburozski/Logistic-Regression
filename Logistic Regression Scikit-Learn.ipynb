# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df =pd.read_csv("C:\\Users\\Eddie\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL\\DATA\\hearing_test.csv")

# %%
df.head()
# We want to use age and physical score to predict whether or not the test result will be a pass or fail
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %%
df.describe()
# Out:
#                age  physical_score  test_result
# count  5000.000000     5000.000000  5000.000000
# mean     51.609000       32.760260     0.600000
# std      11.287001        8.169802     0.489947
# min      18.000000       -0.000000     0.000000
# 25%      43.000000       26.700000     0.000000
# 50%      51.000000       35.300000     1.000000
# 75%      60.000000       38.900000     1.000000
# max      90.000000       50.000000     1.000000

# %%
df.corr()
# We can see test result is negatively correlated with age
# and positively correlated with physical score
# Out:
#                      age  physical_score  test_result
# age             1.000000       -0.782146    -0.683171
# physical_score -0.782146        1.000000     0.792716
# test_result    -0.683171        0.792716     1.000000

# %%
df['test_result'].value_counts()
# Out:
# 1    3000
# 0    2000
# Name: test_result, dtype: int64

# %%
sns.countplot(data = df, x = 'test_result')
# Out:
# <AxesSubplot:xlabel='test_result', ylabel='count'>

# %%
plt.figure(figsize = (12,6), dpi = 200)
sns.boxplot(data = df, y = 'age', x = 'test_result')
# Out:
# <AxesSubplot:xlabel='test_result', ylabel='age'>

# %%
sns.boxplot(data = df, y = 'physical_score', x = 'test_result')
# Out:
# <AxesSubplot:xlabel='test_result', ylabel='physical_score'>

# %%
plt.figure(figsize = (10,6), dpi = 150)
sns.scatterplot(data = df, x = 'age', y = 'physical_score', hue = 'test_result', alpha = 0.5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='physical_score'>

# %%
sns.pairplot(data = df, hue = 'test_result')

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x = 'physical_score', y ='test_result', data = df)
# Out:
# <AxesSubplot:xlabel='physical_score', ylabel='test_result'>

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111, projection = '3d')

ax.scatter(xs = df['age'], ys = df['physical_score'], zs = df['test_result'], c = df['test_result'], alpha = 0.5)
